# %% [markdown]
# # Initialize Locational Marginal Prices Client

# %%
client = LMPClient()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.data.gridstatus_client import LMPClient
#       2 client = LMPClient()
#
# ModuleNotFoundError: No module named 'src'

# %% [markdown]
# # CAISO - pull 2+ years for training

# %%
caiso_lmps = client.get_caiso_lmp(start="Jan 1, 2023", end="Dec 31, 2024")
caiso_lmps.to_parquet("data/raw/caiso_lmps_2023_2024.parquet")

# %% [markdown]
# # ERCOT - may not have data before mid 2023

# %%
ercot_lmps = client.get_ercot_lmp(start="May 1, 2023", end="Dec 31, 2024")
ercot_lmps.to_parquet("data/raw/ercot_lmps_2023_2024.parquet)
